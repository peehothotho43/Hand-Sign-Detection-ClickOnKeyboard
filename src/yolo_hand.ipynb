# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO

save_dir = '/Users/supakornsuksawat/Documents/Python Project Folder/Model'

model = YOLO("yolov8n.pt")

results = model.train(
    data='/Users/supakornsuksawat/Documents/Hand Gesture.v6i.yolov5pytorch/data.yaml',
    epochs=50,
    imgsz=420,
    project=save_dir,  # Save all training outputs to Drive
    name='hand_detection_model_training_02'
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.155 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.106 🚀 Python-3.12.6 torch-2.6.0 CPU (Apple M2)
# ...

# %%
model = YOLO('/Users/supakornsuksawat/Documents/Python Project Folder/Model/hand_detection_model_training_022/weights/best.pt')

# %%
model.predict(source=0, show=True, conf=0.5)
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 (no detections), 74.2ms
# 0: 384x640 (no detections), 58.5ms
# 0: 384x640 (no detections), 66.6ms
# 0: 384x640 (no detections), 62.7ms
# 0: 384x640 (no detections), 62.1ms
# 0: 384x640 (no detections), 54.5ms
# 0: 384x640 (no detections), 66.0ms
# 0: 384x640 (no detections), 77.6ms
# 0: 384x640 (no detections), 59.7ms
# ...
